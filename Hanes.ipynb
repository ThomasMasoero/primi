# %%
import pandas as pd

df = pd.read_excel (r'C:\Users\thomas\Documents\università\valetti\line.xlsx') 
df.columns = ['s', 'v_norm', 'v_inib', 'conc_inib'] 
msus= input("Enter the measure unit of substrate:")
msuv= input("Enter the measure unit of velocity :")
msui=input("Enter the measure unit of inhibent if present:")
print (df)
print('substrate:'+msus)
print('velocity:'+msuv)
print('inhibent concentration:'+msui)
# Out:
# Enter the measure unit of substrate:uM
# Enter the measure unit of velocity :uM/s
# Enter the measure unit of inhibent if present:uM
#        s   v_norm   v_inib  conc_inib
# 0  0.033  0.01008  0.00657        5.0
# 1  0.050  0.01215  0.00837        NaN
# 2  0.066  0.01341  0.00981        NaN
# 3  0.100  0.01521  0.01179        NaN
# 4  0.200  0.01728  0.01476        NaN
# substrate:uM
# velocity:uM/s
# inhibent concentration:uM

# %%
from bokeh.plotting import figure, show, output_notebook
param = dict(width = 700, height = 250,
             tools = 'wheel_zoom, reset,pan, box_zoom',
             tooltips = [( 'substrate',   '@s'), ( 'velocity',   '@v')],
            )
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
df['s/v_norm'] = df['s'] / df['v_norm']
df
# Out:
#        s   v_norm   v_inib  conc_inib   s/v_norm
# 0  0.033  0.01008  0.00657        5.0   3.273810
# 1  0.050  0.01215  0.00837        NaN   4.115226
# 2  0.066  0.01341  0.00981        NaN   4.921700
# 3  0.100  0.01521  0.01179        NaN   6.574622
# 4  0.200  0.01728  0.01476        NaN  11.574074

# %%
p = figure(x_axis_label='Concentrazione substrato '+msus,
           y_axis_label='Velocità di reazione '+msuv,
           **param,
           )
p.circle( 's', 'v_norm', source=df ) # Plotto i punti (s,v)
show( p )
# Out:
#   <div class="bk-root" id="b2470405-f069-434a-b69b-2e351119a6ac"></div>

# %%
from scipy.stats import linregress
slope, intercept, r_value, p_value, std_err = linregress( df['s'], df['s/v_norm'] )
'slope {}, intercept {}'.format(slope,intercept)
# Out:
# 'slope 49.68279086514261, intercept 1.6303718039668231'

# %%
from numpy import array

# %%
#problemi col grafico
xmax = df['s/v_norm'].max()
x = array( [-0.5, 0.5] )            
y = x * slope + intercept 

p = figure(title = 'Hanes', x_axis_label='s', y_axis_label='s/v', **param)
p.circle( 's', 's/v_norm', source=df )
p.line( x, y, color='orange')      
show( p )
Vmax = 1/slope
Km = intercept*Vmax
print('Vmax : '+str(Vmax)+' '+msuv+' Km : '+str(Km)+' '+msus)
# Out:
#   <div class="bk-root" id="d5605a4a-c42a-4256-ac25-40df5df84b83"></div>
# Vmax : 0.02012769376652709 uM/s Km : 0.032815624395824555 uM
